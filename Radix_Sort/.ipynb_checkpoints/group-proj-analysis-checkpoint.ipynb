# %%
import sys
sys.path.append("/scratch/group/csce435-f24/python-3.10.4/lib/python3.10/site-packages")
sys.path.append("/scratch/group/csce435-f24/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
# Out:
# Warning: Roundtrip module could not be loaded. Requires jupyter notebook version <= 7.x.

# %% [markdown]
# Read all files

# %%
#1_trial is a name of a folder containing the cali files, you may create a folder with a different name and replace the folder name here
tk = th.Thicket.from_caliperreader(glob("*.cali"))
# Out:
# (1/2) Reading Files: 100%|██████████| 1/1 [00:00<00:00, 15.39it/s]
# 0it [00:00, ?it/s]

# %% [markdown]
# View Calltree

# %%
print(tk.tree(metric_column="Avg time/rank"))
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2024.1.0
#
# 0.017 main
# ├─ 0.000 data_init_runtime
# ├─ 0.002 MPI_Bcast
# ├─ 0.000 comm
# │  ├─ 0.000 comm_small
# │  │  └─ 0.000 MPI_Scatter
# │  └─ 0.000 comm_large
# │     └─ 0.000 MPI_Gather
# ├─ 0.000 comp
# │  ├─ 0.000 comp_small
# │  └─ 0.000 comp_large
# └─ 0.000 correctness_check
# 0.000 MPI_Finalize
# 0.000 MPI_Initialized
# 0.000 MPI_Finalized
# 0.015 MPI_Comm_dup
#
# Legend (Metric: Avg time/rank Min: 0.00 Max: 0.02 indices: {'profile': 54582209})
# █ 0.02 - 0.02
# █ 0.01 - 0.02
# █ 0.01 - 0.01
# █ 0.01 - 0.01
# █ 0.00 - 0.01
# █ 0.00 - 0.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %% [markdown]
# Group Performance data by `matrix_size` in the Thicket metadata table.

# %%
tk.metadata_column_to_perfdata("num_procs")
tk.metadata_column_to_perfdata("input_size")

tk.dataframe = tk.dataframe.reset_index().set_index(["node", "num_procs", "input_size"]).sort_index()

tk.dataframe.head(10)
# Out:
# /scratch/group/csce435-f24/thicket/thicket/thicket.py:634: UserWarning: Column num_procs already exists. Set 'overwrite=True' to force update the column.
#   warnings.warn(
# /scratch/group/csce435-f24/thicket/thicket/thicket.py:634: UserWarning: Column input_size already exists. Set 'overwrite=True' to force update the column.
#   warnings.warn(
#                                                                            profile  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024        1134066059
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024        1134066059
# {'name': 'comm', 'type': 'function'}              16        1024        1134066059
# {'name': 'comm_large', 'type': 'function'}        16        1024        1134066059
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024        1134066059
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024        1134066059
# {'name': 'comp', 'type': 'function'}              16        1024        1134066059
# {'name': 'comp_small', 'type': 'function'}        16        1024        1134066059
# {'name': 'comp_large', 'type': 'function'}        16        1024        1134066059
# {'name': 'correctness_check', 'type': 'function'} 16        1024        1134066059
#
#                                                                          nid  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024         1.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024         2.0
# {'name': 'comm', 'type': 'function'}              16        1024         3.0
# {'name': 'comm_large', 'type': 'function'}        16        1024         4.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024         5.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024         8.0
# {'name': 'comp', 'type': 'function'}              16        1024         6.0
# {'name': 'comp_small', 'type': 'function'}        16        1024         7.0
# {'name': 'comp_large', 'type': 'function'}        16        1024         9.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024        10.0
#
#                                                                          spot.channel  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024        regionprofile
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024        regionprofile
# {'name': 'comm', 'type': 'function'}              16        1024        regionprofile
# {'name': 'comm_large', 'type': 'function'}        16        1024        regionprofile
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024        regionprofile
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024        regionprofile
# {'name': 'comp', 'type': 'function'}              16        1024        regionprofile
# {'name': 'comp_small', 'type': 'function'}        16        1024        regionprofile
# {'name': 'comp_large', 'type': 'function'}        16        1024        regionprofile
# {'name': 'correctness_check', 'type': 'function'} 16        1024        regionprofile
#
#                                                                         Min time/rank  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024             0.007366
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024             0.000045
# {'name': 'comm', 'type': 'function'}              16        1024             0.006262
# {'name': 'comm_large', 'type': 'function'}        16        1024             0.006241
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024             0.004754
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024             0.000030
# {'name': 'comp', 'type': 'function'}              16        1024             0.000024
# {'name': 'comp_small', 'type': 'function'}        16        1024             0.000015
# {'name': 'comp_large', 'type': 'function'}        16        1024             0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024             0.000008
#
#                                                                         Max time/rank  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024             0.009518
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024             0.000045
# {'name': 'comm', 'type': 'function'}              16        1024             0.006466
# {'name': 'comm_large', 'type': 'function'}        16        1024             0.006447
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024             0.005741
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024             0.001188
# {'name': 'comp', 'type': 'function'}              16        1024             0.000061
# {'name': 'comp_small', 'type': 'function'}        16        1024             0.000016
# {'name': 'comp_large', 'type': 'function'}        16        1024             0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024             0.000008
#
#                                                                         Avg time/rank  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024             0.007551
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024             0.000045
# {'name': 'comm', 'type': 'function'}              16        1024             0.006333
# {'name': 'comm_large', 'type': 'function'}        16        1024             0.006311
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024             0.005625
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024             0.000133
# {'name': 'comp', 'type': 'function'}              16        1024             0.000027
# {'name': 'comp_small', 'type': 'function'}        16        1024             0.000015
# {'name': 'comp_large', 'type': 'function'}        16        1024             0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024             0.000008
#
#                                                                         Total time  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024          0.120810
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024          0.000045
# {'name': 'comm', 'type': 'function'}              16        1024          0.101323
# {'name': 'comm_large', 'type': 'function'}        16        1024          0.100974
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024          0.089995
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024          0.002126
# {'name': 'comp', 'type': 'function'}              16        1024          0.000432
# {'name': 'comp_small', 'type': 'function'}        16        1024          0.000243
# {'name': 'comp_large', 'type': 'function'}        16        1024          0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024          0.000008
#
#                                                                         Variance time/rank  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                       0.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                       0.0
# {'name': 'comm', 'type': 'function'}              16        1024                       0.0
# {'name': 'comm_large', 'type': 'function'}        16        1024                       0.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                       0.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                       0.0
# {'name': 'comp', 'type': 'function'}              16        1024                       0.0
# {'name': 'comp_small', 'type': 'function'}        16        1024                       0.0
# {'name': 'comp_large', 'type': 'function'}        16        1024                       0.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024                       0.0
#
#                                                                         Calls/rank (min)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                     1.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                     1.0
# {'name': 'comm', 'type': 'function'}              16        1024                     2.0
# {'name': 'comm_large', 'type': 'function'}        16        1024                     2.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                     1.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                     1.0
# {'name': 'comp', 'type': 'function'}              16        1024                     1.0
# {'name': 'comp_small', 'type': 'function'}        16        1024                     1.0
# {'name': 'comp_large', 'type': 'function'}        16        1024                     1.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024                     1.0
#
#                                                                         Calls/rank (avg)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                  1.0000
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                  1.0000
# {'name': 'comm', 'type': 'function'}              16        1024                  2.0000
# {'name': 'comm_large', 'type': 'function'}        16        1024                  2.0000
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                  1.0000
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                  1.0000
# {'name': 'comp', 'type': 'function'}              16        1024                  1.0625
# {'name': 'comp_small', 'type': 'function'}        16        1024                  1.0000
# {'name': 'comp_large', 'type': 'function'}        16        1024                  1.0000
# {'name': 'correctness_check', 'type': 'function'} 16        1024                  1.0000
#
#                                                                         Calls/rank (max)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                     1.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                     1.0
# {'name': 'comm', 'type': 'function'}              16        1024                     2.0
# {'name': 'comm_large', 'type': 'function'}        16        1024                     2.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                     1.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                     1.0
# {'name': 'comp', 'type': 'function'}              16        1024                     2.0
# {'name': 'comp_small', 'type': 'function'}        16        1024                     1.0
# {'name': 'comp_large', 'type': 'function'}        16        1024                     1.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024                     1.0
#
#                                                                         Calls/rank (total)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                      16.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                       1.0
# {'name': 'comm', 'type': 'function'}              16        1024                      32.0
# {'name': 'comm_large', 'type': 'function'}        16        1024                      32.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                      16.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                      16.0
# {'name': 'comp', 'type': 'function'}              16        1024                      17.0
# {'name': 'comp_small', 'type': 'function'}        16        1024                      16.0
# {'name': 'comp_large', 'type': 'function'}        16        1024                       1.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024                       1.0
#
#                                                                         Min time/rank (exc)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                   0.001006
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                   0.000045
# {'name': 'comm', 'type': 'function'}              16        1024                   0.000019
# {'name': 'comm_large', 'type': 'function'}        16        1024                   0.000506
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                   0.004754
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                   0.000030
# {'name': 'comp', 'type': 'function'}              16        1024                   0.000009
# {'name': 'comp_small', 'type': 'function'}        16        1024                   0.000015
# {'name': 'comp_large', 'type': 'function'}        16        1024                   0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024                   0.000008
#
#                                                                         Max time/rank (exc)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                   0.002939
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                   0.000045
# {'name': 'comm', 'type': 'function'}              16        1024                   0.000023
# {'name': 'comm_large', 'type': 'function'}        16        1024                   0.000580
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                   0.005741
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                   0.001188
# {'name': 'comp', 'type': 'function'}              16        1024                   0.000016
# {'name': 'comp_small', 'type': 'function'}        16        1024                   0.000016
# {'name': 'comp_large', 'type': 'function'}        16        1024                   0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024                   0.000008
#
#                                                                         Avg time/rank (exc)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                   0.001188
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                   0.000045
# {'name': 'comm', 'type': 'function'}              16        1024                   0.000022
# {'name': 'comm_large', 'type': 'function'}        16        1024                   0.000553
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                   0.005625
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                   0.000133
# {'name': 'comp', 'type': 'function'}              16        1024                   0.000010
# {'name': 'comp_small', 'type': 'function'}        16        1024                   0.000015
# {'name': 'comp_large', 'type': 'function'}        16        1024                   0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024                   0.000008
#
#                                                                         Total time (exc)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                0.019002
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                0.000045
# {'name': 'comm', 'type': 'function'}              16        1024                0.000349
# {'name': 'comm_large', 'type': 'function'}        16        1024                0.008853
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                0.089995
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                0.002126
# {'name': 'comp', 'type': 'function'}              16        1024                0.000159
# {'name': 'comp_small', 'type': 'function'}        16        1024                0.000243
# {'name': 'comp_large', 'type': 'function'}        16        1024                0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024                0.000008
#
#                                                                                      name
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                     main
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024        data_init_runtime
# {'name': 'comm', 'type': 'function'}              16        1024                     comm
# {'name': 'comm_large', 'type': 'function'}        16        1024               comm_large
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024              MPI_Scatter
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024               MPI_Gather
# {'name': 'comp', 'type': 'function'}              16        1024                     comp
# {'name': 'comp_small', 'type': 'function'}        16        1024               comp_small
# {'name': 'comp_large', 'type': 'function'}        16        1024               comp_large
# {'name': 'correctness_check', 'type': 'function'} 16        1024        correctness_check

# %%
# Define common variables
processes = [16]
input_sizes = [1024]

# %%
# Change font size for all plots
plt.rcParams.update({"font.size": 20})

# %%
print(tk.dataframe)
# Out:
#                                                                            profile  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024        1134066059
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024        1134066059
# {'name': 'comm', 'type': 'function'}              16        1024        1134066059
# {'name': 'comm_large', 'type': 'function'}        16        1024        1134066059
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024        1134066059
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024        1134066059
# {'name': 'comp', 'type': 'function'}              16        1024        1134066059
# {'name': 'comp_small', 'type': 'function'}        16        1024        1134066059
# {'name': 'comp_large', 'type': 'function'}        16        1024        1134066059
# {'name': 'correctness_check', 'type': 'function'} 16        1024        1134066059
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024        1134066059
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024        1134066059
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024        1134066059
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024        1134066059
#
#                                                                          nid  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024         1.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024         2.0
# {'name': 'comm', 'type': 'function'}              16        1024         3.0
# {'name': 'comm_large', 'type': 'function'}        16        1024         4.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024         5.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024         8.0
# {'name': 'comp', 'type': 'function'}              16        1024         6.0
# {'name': 'comp_small', 'type': 'function'}        16        1024         7.0
# {'name': 'comp_large', 'type': 'function'}        16        1024         9.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024        10.0
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024        12.0
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024        14.0
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024        16.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024        18.0
#
#                                                                          spot.channel  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024        regionprofile
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024        regionprofile
# {'name': 'comm', 'type': 'function'}              16        1024        regionprofile
# {'name': 'comm_large', 'type': 'function'}        16        1024        regionprofile
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024        regionprofile
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024        regionprofile
# {'name': 'comp', 'type': 'function'}              16        1024        regionprofile
# {'name': 'comp_small', 'type': 'function'}        16        1024        regionprofile
# {'name': 'comp_large', 'type': 'function'}        16        1024        regionprofile
# {'name': 'correctness_check', 'type': 'function'} 16        1024        regionprofile
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024        regionprofile
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024        regionprofile
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024        regionprofile
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024        regionprofile
#
#                                                                         Min time/rank  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024             0.007366
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024             0.000045
# {'name': 'comm', 'type': 'function'}              16        1024             0.006262
# {'name': 'comm_large', 'type': 'function'}        16        1024             0.006241
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024             0.004754
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024             0.000030
# {'name': 'comp', 'type': 'function'}              16        1024             0.000024
# {'name': 'comp_small', 'type': 'function'}        16        1024             0.000015
# {'name': 'comp_large', 'type': 'function'}        16        1024             0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024             0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024             0.000005
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024             0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024             0.000004
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024             0.002929
#
#                                                                         Max time/rank  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024             0.009518
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024             0.000045
# {'name': 'comm', 'type': 'function'}              16        1024             0.006466
# {'name': 'comm_large', 'type': 'function'}        16        1024             0.006447
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024             0.005741
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024             0.001188
# {'name': 'comp', 'type': 'function'}              16        1024             0.000061
# {'name': 'comp_small', 'type': 'function'}        16        1024             0.000016
# {'name': 'comp_large', 'type': 'function'}        16        1024             0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024             0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024             0.000005
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024             0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024             0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024             0.005120
#
#                                                                         Avg time/rank  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024             0.007551
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024             0.000045
# {'name': 'comm', 'type': 'function'}              16        1024             0.006333
# {'name': 'comm_large', 'type': 'function'}        16        1024             0.006311
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024             0.005625
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024             0.000133
# {'name': 'comp', 'type': 'function'}              16        1024             0.000027
# {'name': 'comp_small', 'type': 'function'}        16        1024             0.000015
# {'name': 'comp_large', 'type': 'function'}        16        1024             0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024             0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024             0.000005
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024             0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024             0.000004
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024             0.004952
#
#                                                                         Total time  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024          0.120810
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024          0.000045
# {'name': 'comm', 'type': 'function'}              16        1024          0.101323
# {'name': 'comm_large', 'type': 'function'}        16        1024          0.100974
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024          0.089995
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024          0.002126
# {'name': 'comp', 'type': 'function'}              16        1024          0.000432
# {'name': 'comp_small', 'type': 'function'}        16        1024          0.000243
# {'name': 'comp_large', 'type': 'function'}        16        1024          0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024          0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024          0.000078
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024          0.000081
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024          0.000070
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024          0.079231
#
#                                                                         Variance time/rank  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                       0.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                       0.0
# {'name': 'comm', 'type': 'function'}              16        1024                       0.0
# {'name': 'comm_large', 'type': 'function'}        16        1024                       0.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                       0.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                       0.0
# {'name': 'comp', 'type': 'function'}              16        1024                       0.0
# {'name': 'comp_small', 'type': 'function'}        16        1024                       0.0
# {'name': 'comp_large', 'type': 'function'}        16        1024                       0.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024                       0.0
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                       0.0
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                       0.0
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                       0.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                       0.0
#
#                                                                         Calls/rank (min)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                     1.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                     1.0
# {'name': 'comm', 'type': 'function'}              16        1024                     2.0
# {'name': 'comm_large', 'type': 'function'}        16        1024                     2.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                     1.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                     1.0
# {'name': 'comp', 'type': 'function'}              16        1024                     1.0
# {'name': 'comp_small', 'type': 'function'}        16        1024                     1.0
# {'name': 'comp_large', 'type': 'function'}        16        1024                     1.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024                     1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                     1.0
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                     1.0
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                     1.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                     1.0
#
#                                                                         Calls/rank (avg)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                  1.0000
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                  1.0000
# {'name': 'comm', 'type': 'function'}              16        1024                  2.0000
# {'name': 'comm_large', 'type': 'function'}        16        1024                  2.0000
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                  1.0000
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                  1.0000
# {'name': 'comp', 'type': 'function'}              16        1024                  1.0625
# {'name': 'comp_small', 'type': 'function'}        16        1024                  1.0000
# {'name': 'comp_large', 'type': 'function'}        16        1024                  1.0000
# {'name': 'correctness_check', 'type': 'function'} 16        1024                  1.0000
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                  1.0000
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                  1.0000
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                  1.0000
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                  1.0000
#
#                                                                         Calls/rank (max)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                     1.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                     1.0
# {'name': 'comm', 'type': 'function'}              16        1024                     2.0
# {'name': 'comm_large', 'type': 'function'}        16        1024                     2.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                     1.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                     1.0
# {'name': 'comp', 'type': 'function'}              16        1024                     2.0
# {'name': 'comp_small', 'type': 'function'}        16        1024                     1.0
# {'name': 'comp_large', 'type': 'function'}        16        1024                     1.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024                     1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                     1.0
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                     1.0
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                     1.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                     1.0
#
#                                                                         Calls/rank (total)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                      16.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                       1.0
# {'name': 'comm', 'type': 'function'}              16        1024                      32.0
# {'name': 'comm_large', 'type': 'function'}        16        1024                      32.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                      16.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                      16.0
# {'name': 'comp', 'type': 'function'}              16        1024                      17.0
# {'name': 'comp_small', 'type': 'function'}        16        1024                      16.0
# {'name': 'comp_large', 'type': 'function'}        16        1024                       1.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024                       1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                      16.0
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                      16.0
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                      16.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                      16.0
#
#                                                                         Min time/rank (exc)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                   0.001006
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                   0.000045
# {'name': 'comm', 'type': 'function'}              16        1024                   0.000019
# {'name': 'comm_large', 'type': 'function'}        16        1024                   0.000506
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                   0.004754
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                   0.000030
# {'name': 'comp', 'type': 'function'}              16        1024                   0.000009
# {'name': 'comp_small', 'type': 'function'}        16        1024                   0.000015
# {'name': 'comp_large', 'type': 'function'}        16        1024                   0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024                   0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                   0.000005
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                   0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                   0.000004
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                   0.002929
#
#                                                                         Max time/rank (exc)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                   0.002939
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                   0.000045
# {'name': 'comm', 'type': 'function'}              16        1024                   0.000023
# {'name': 'comm_large', 'type': 'function'}        16        1024                   0.000580
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                   0.005741
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                   0.001188
# {'name': 'comp', 'type': 'function'}              16        1024                   0.000016
# {'name': 'comp_small', 'type': 'function'}        16        1024                   0.000016
# {'name': 'comp_large', 'type': 'function'}        16        1024                   0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024                   0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                   0.000005
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                   0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                   0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                   0.005120
#
#                                                                         Avg time/rank (exc)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                   0.001188
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                   0.000045
# {'name': 'comm', 'type': 'function'}              16        1024                   0.000022
# {'name': 'comm_large', 'type': 'function'}        16        1024                   0.000553
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                   0.005625
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                   0.000133
# {'name': 'comp', 'type': 'function'}              16        1024                   0.000010
# {'name': 'comp_small', 'type': 'function'}        16        1024                   0.000015
# {'name': 'comp_large', 'type': 'function'}        16        1024                   0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024                   0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                   0.000005
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                   0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                   0.000004
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                   0.004952
#
#                                                                         Total time (exc)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                0.019002
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                0.000045
# {'name': 'comm', 'type': 'function'}              16        1024                0.000349
# {'name': 'comm_large', 'type': 'function'}        16        1024                0.008853
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                0.089995
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                0.002126
# {'name': 'comp', 'type': 'function'}              16        1024                0.000159
# {'name': 'comp_small', 'type': 'function'}        16        1024                0.000243
# {'name': 'comp_large', 'type': 'function'}        16        1024                0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024                0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                0.000078
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                0.000081
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                0.000070
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                0.079231
#
#                                                                                      name
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                     main
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024        data_init_runtime
# {'name': 'comm', 'type': 'function'}              16        1024                     comm
# {'name': 'comm_large', 'type': 'function'}        16        1024               comm_large
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024              MPI_Scatter
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024               MPI_Gather
# {'name': 'comp', 'type': 'function'}              16        1024                     comp
# {'name': 'comp_small', 'type': 'function'}        16        1024               comp_small
# {'name': 'comp_large', 'type': 'function'}        16        1024               comp_large
# {'name': 'correctness_check', 'type': 'function'} 16        1024        correctness_check
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024             MPI_Finalize
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024          MPI_Initialized
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024            MPI_Finalized
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024             MPI_Comm_dup

# %%
def plot_pandas(df, title, xlabel, ylabel):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        figsize=(15,7)
    )
    return plot

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure(figsize=(15,7))
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(matrix_sizes)
    plt.xscale("log", base=2)
    plt.xticks(threads)
    ax.set_xticklabels(threads)
    plt.show()
    return fig, ax

# %%
tk.dataframe.keys()
# Out:
# Index(['profile', 'nid', 'spot.channel', 'Min time/rank', 'Max time/rank',
#        'Avg time/rank', 'Total time', 'Variance time/rank', 'Calls/rank (min)',
#        'Calls/rank (avg)', 'Calls/rank (max)', 'Calls/rank (total)',
#        'Min time/rank (exc)', 'Max time/rank (exc)', 'Avg time/rank (exc)',
#        'Total time (exc)', 'name'],
#       dtype='object')

# %%
tk.dataframe
# Out:
#                                                                            profile  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024        1134066059
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024        1134066059
# {'name': 'comm', 'type': 'function'}              16        1024        1134066059
# {'name': 'comm_large', 'type': 'function'}        16        1024        1134066059
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024        1134066059
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024        1134066059
# {'name': 'comp', 'type': 'function'}              16        1024        1134066059
# {'name': 'comp_small', 'type': 'function'}        16        1024        1134066059
# {'name': 'comp_large', 'type': 'function'}        16        1024        1134066059
# {'name': 'correctness_check', 'type': 'function'} 16        1024        1134066059
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024        1134066059
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024        1134066059
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024        1134066059
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024        1134066059
#
#                                                                          nid  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024         1.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024         2.0
# {'name': 'comm', 'type': 'function'}              16        1024         3.0
# {'name': 'comm_large', 'type': 'function'}        16        1024         4.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024         5.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024         8.0
# {'name': 'comp', 'type': 'function'}              16        1024         6.0
# {'name': 'comp_small', 'type': 'function'}        16        1024         7.0
# {'name': 'comp_large', 'type': 'function'}        16        1024         9.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024        10.0
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024        12.0
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024        14.0
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024        16.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024        18.0
#
#                                                                          spot.channel  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024        regionprofile
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024        regionprofile
# {'name': 'comm', 'type': 'function'}              16        1024        regionprofile
# {'name': 'comm_large', 'type': 'function'}        16        1024        regionprofile
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024        regionprofile
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024        regionprofile
# {'name': 'comp', 'type': 'function'}              16        1024        regionprofile
# {'name': 'comp_small', 'type': 'function'}        16        1024        regionprofile
# {'name': 'comp_large', 'type': 'function'}        16        1024        regionprofile
# {'name': 'correctness_check', 'type': 'function'} 16        1024        regionprofile
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024        regionprofile
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024        regionprofile
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024        regionprofile
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024        regionprofile
#
#                                                                         Min time/rank  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024             0.007366
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024             0.000045
# {'name': 'comm', 'type': 'function'}              16        1024             0.006262
# {'name': 'comm_large', 'type': 'function'}        16        1024             0.006241
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024             0.004754
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024             0.000030
# {'name': 'comp', 'type': 'function'}              16        1024             0.000024
# {'name': 'comp_small', 'type': 'function'}        16        1024             0.000015
# {'name': 'comp_large', 'type': 'function'}        16        1024             0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024             0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024             0.000005
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024             0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024             0.000004
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024             0.002929
#
#                                                                         Max time/rank  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024             0.009518
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024             0.000045
# {'name': 'comm', 'type': 'function'}              16        1024             0.006466
# {'name': 'comm_large', 'type': 'function'}        16        1024             0.006447
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024             0.005741
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024             0.001188
# {'name': 'comp', 'type': 'function'}              16        1024             0.000061
# {'name': 'comp_small', 'type': 'function'}        16        1024             0.000016
# {'name': 'comp_large', 'type': 'function'}        16        1024             0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024             0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024             0.000005
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024             0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024             0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024             0.005120
#
#                                                                         Avg time/rank  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024             0.007551
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024             0.000045
# {'name': 'comm', 'type': 'function'}              16        1024             0.006333
# {'name': 'comm_large', 'type': 'function'}        16        1024             0.006311
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024             0.005625
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024             0.000133
# {'name': 'comp', 'type': 'function'}              16        1024             0.000027
# {'name': 'comp_small', 'type': 'function'}        16        1024             0.000015
# {'name': 'comp_large', 'type': 'function'}        16        1024             0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024             0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024             0.000005
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024             0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024             0.000004
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024             0.004952
#
#                                                                         Total time  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024          0.120810
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024          0.000045
# {'name': 'comm', 'type': 'function'}              16        1024          0.101323
# {'name': 'comm_large', 'type': 'function'}        16        1024          0.100974
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024          0.089995
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024          0.002126
# {'name': 'comp', 'type': 'function'}              16        1024          0.000432
# {'name': 'comp_small', 'type': 'function'}        16        1024          0.000243
# {'name': 'comp_large', 'type': 'function'}        16        1024          0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024          0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024          0.000078
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024          0.000081
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024          0.000070
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024          0.079231
#
#                                                                         Variance time/rank  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                       0.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                       0.0
# {'name': 'comm', 'type': 'function'}              16        1024                       0.0
# {'name': 'comm_large', 'type': 'function'}        16        1024                       0.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                       0.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                       0.0
# {'name': 'comp', 'type': 'function'}              16        1024                       0.0
# {'name': 'comp_small', 'type': 'function'}        16        1024                       0.0
# {'name': 'comp_large', 'type': 'function'}        16        1024                       0.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024                       0.0
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                       0.0
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                       0.0
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                       0.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                       0.0
#
#                                                                         Calls/rank (min)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                     1.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                     1.0
# {'name': 'comm', 'type': 'function'}              16        1024                     2.0
# {'name': 'comm_large', 'type': 'function'}        16        1024                     2.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                     1.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                     1.0
# {'name': 'comp', 'type': 'function'}              16        1024                     1.0
# {'name': 'comp_small', 'type': 'function'}        16        1024                     1.0
# {'name': 'comp_large', 'type': 'function'}        16        1024                     1.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024                     1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                     1.0
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                     1.0
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                     1.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                     1.0
#
#                                                                         Calls/rank (avg)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                  1.0000
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                  1.0000
# {'name': 'comm', 'type': 'function'}              16        1024                  2.0000
# {'name': 'comm_large', 'type': 'function'}        16        1024                  2.0000
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                  1.0000
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                  1.0000
# {'name': 'comp', 'type': 'function'}              16        1024                  1.0625
# {'name': 'comp_small', 'type': 'function'}        16        1024                  1.0000
# {'name': 'comp_large', 'type': 'function'}        16        1024                  1.0000
# {'name': 'correctness_check', 'type': 'function'} 16        1024                  1.0000
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                  1.0000
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                  1.0000
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                  1.0000
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                  1.0000
#
#                                                                         Calls/rank (max)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                     1.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                     1.0
# {'name': 'comm', 'type': 'function'}              16        1024                     2.0
# {'name': 'comm_large', 'type': 'function'}        16        1024                     2.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                     1.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                     1.0
# {'name': 'comp', 'type': 'function'}              16        1024                     2.0
# {'name': 'comp_small', 'type': 'function'}        16        1024                     1.0
# {'name': 'comp_large', 'type': 'function'}        16        1024                     1.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024                     1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                     1.0
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                     1.0
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                     1.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                     1.0
#
#                                                                         Calls/rank (total)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                      16.0
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                       1.0
# {'name': 'comm', 'type': 'function'}              16        1024                      32.0
# {'name': 'comm_large', 'type': 'function'}        16        1024                      32.0
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                      16.0
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                      16.0
# {'name': 'comp', 'type': 'function'}              16        1024                      17.0
# {'name': 'comp_small', 'type': 'function'}        16        1024                      16.0
# {'name': 'comp_large', 'type': 'function'}        16        1024                       1.0
# {'name': 'correctness_check', 'type': 'function'} 16        1024                       1.0
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                      16.0
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                      16.0
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                      16.0
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                      16.0
#
#                                                                         Min time/rank (exc)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                   0.001006
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                   0.000045
# {'name': 'comm', 'type': 'function'}              16        1024                   0.000019
# {'name': 'comm_large', 'type': 'function'}        16        1024                   0.000506
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                   0.004754
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                   0.000030
# {'name': 'comp', 'type': 'function'}              16        1024                   0.000009
# {'name': 'comp_small', 'type': 'function'}        16        1024                   0.000015
# {'name': 'comp_large', 'type': 'function'}        16        1024                   0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024                   0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                   0.000005
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                   0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                   0.000004
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                   0.002929
#
#                                                                         Max time/rank (exc)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                   0.002939
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                   0.000045
# {'name': 'comm', 'type': 'function'}              16        1024                   0.000023
# {'name': 'comm_large', 'type': 'function'}        16        1024                   0.000580
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                   0.005741
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                   0.001188
# {'name': 'comp', 'type': 'function'}              16        1024                   0.000016
# {'name': 'comp_small', 'type': 'function'}        16        1024                   0.000016
# {'name': 'comp_large', 'type': 'function'}        16        1024                   0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024                   0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                   0.000005
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                   0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                   0.000005
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                   0.005120
#
#                                                                         Avg time/rank (exc)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                   0.001188
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                   0.000045
# {'name': 'comm', 'type': 'function'}              16        1024                   0.000022
# {'name': 'comm_large', 'type': 'function'}        16        1024                   0.000553
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                   0.005625
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                   0.000133
# {'name': 'comp', 'type': 'function'}              16        1024                   0.000010
# {'name': 'comp_small', 'type': 'function'}        16        1024                   0.000015
# {'name': 'comp_large', 'type': 'function'}        16        1024                   0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024                   0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                   0.000005
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                   0.000005
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                   0.000004
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                   0.004952
#
#                                                                         Total time (exc)  \
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                0.019002
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024                0.000045
# {'name': 'comm', 'type': 'function'}              16        1024                0.000349
# {'name': 'comm_large', 'type': 'function'}        16        1024                0.008853
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024                0.089995
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024                0.002126
# {'name': 'comp', 'type': 'function'}              16        1024                0.000159
# {'name': 'comp_small', 'type': 'function'}        16        1024                0.000243
# {'name': 'comp_large', 'type': 'function'}        16        1024                0.000029
# {'name': 'correctness_check', 'type': 'function'} 16        1024                0.000008
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024                0.000078
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024                0.000081
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024                0.000070
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024                0.079231
#
#                                                                                      name
# node                                              num_procs input_size
# {'name': 'main', 'type': 'function'}              16        1024                     main
# {'name': 'data_init_runtime', 'type': 'function'} 16        1024        data_init_runtime
# {'name': 'comm', 'type': 'function'}              16        1024                     comm
# {'name': 'comm_large', 'type': 'function'}        16        1024               comm_large
# {'name': 'MPI_Scatter', 'type': 'function'}       16        1024              MPI_Scatter
# {'name': 'MPI_Gather', 'type': 'function'}        16        1024               MPI_Gather
# {'name': 'comp', 'type': 'function'}              16        1024                     comp
# {'name': 'comp_small', 'type': 'function'}        16        1024               comp_small
# {'name': 'comp_large', 'type': 'function'}        16        1024               comp_large
# {'name': 'correctness_check', 'type': 'function'} 16        1024        correctness_check
# {'name': 'MPI_Finalize', 'type': 'function'}      16        1024             MPI_Finalize
# {'name': 'MPI_Initialized', 'type': 'function'}   16        1024          MPI_Initialized
# {'name': 'MPI_Finalized', 'type': 'function'}     16        1024            MPI_Finalized
# {'name': 'MPI_Comm_dup', 'type': 'function'}      16        1024             MPI_Comm_dup

# %%
for node in tk.graph.traverse():
    
    for m_size in input_sizes:
        
        if node.frame["name"] in ("main"):
            
            y_vals_max = []
#             y_vals_max.append(tk.dataframe.loc[node, "Max time/rank"].loc[2, m_size])
#             y_vals_max.append(tk.dataframe.loc[node, "Max time/rank"].loc[4, m_size])
#             y_vals_max.append(tk.dataframe.loc[node, "Max time/rank"].loc[8, m_size])
            y_vals_max.append(tk.dataframe.loc[node, "Max time/rank"].loc[16, m_size])
#             y_vals_max.append(tk.dataframe.loc[node, "Max time/rank"].loc[32, m_size])
#             y_vals_max.append(tk.dataframe.loc[node, "Max time/rank"].loc[64, m_size])
            
            plt.plot(processes, y_vals_max, marker='o', color='orange')
            plt.xlabel("Number of Processes")
            plt.ylabel('Time (seconds)')
            plt.title(f'{node.frame["name"]} {m_size}x{m_size}')
            plt.savefig(f'results/{m_size}_{node.frame["name"]}.png', bbox_inches = 'tight')
            plt.show()
            plt.clf()
        
        else:
            # Collecting average time values
            y_vals_avg = []
#             y_vals_avg.append(tk.dataframe.loc[node, "Avg time/rank"].loc[2, m_size])
#             y_vals_avg.append(tk.dataframe.loc[node, "Avg time/rank"].loc[4, m_size])
#             y_vals_avg.append(tk.dataframe.loc[node, "Avg time/rank"].loc[8, m_size])
            y_vals_avg.append(tk.dataframe.loc[node, "Avg time/rank"].loc[16, m_size])
#             y_vals_avg.append(tk.dataframe.loc[node, "Avg time/rank"].loc[32, m_size])
#             y_vals_avg.append(tk.dataframe.loc[node, "Avg time/rank"].loc[64, m_size])

            # Collecting minimum time values
            y_vals_min = []
#             y_vals_min.append(tk.dataframe.loc[node, "Min time/rank"].loc[2, m_size])
#             y_vals_min.append(tk.dataframe.loc[node, "Min time/rank"].loc[4, m_size])
#             y_vals_min.append(tk.dataframe.loc[node, "Min time/rank"].loc[8, m_size])
            y_vals_min.append(tk.dataframe.loc[node, "Min time/rank"].loc[16, m_size])
#             y_vals_min.append(tk.dataframe.loc[node, "Min time/rank"].loc[32, m_size])
#             y_vals_min.append(tk.dataframe.loc[node, "Min time/rank"].loc[64, m_size])

            # Collecting maximum time values
            y_vals_max = []
#             y_vals_max.append(tk.dataframe.loc[node, "Max time/rank"].loc[2, m_size])
#             y_vals_max.append(tk.dataframe.loc[node, "Max time/rank"].loc[4, m_size])
#             y_vals_max.append(tk.dataframe.loc[node, "Max time/rank"].loc[8, m_size])
            y_vals_max.append(tk.dataframe.loc[node, "Max time/rank"].loc[16, m_size])
#             y_vals_max.append(tk.dataframe.loc[node, "Max time/rank"].loc[32, m_size])
#             y_vals_max.append(tk.dataframe.loc[node, "Max time/rank"].loc[64, m_size])

            plt.plot(processes, y_vals_avg, marker='o', color='blue', label='Average Time')
            plt.plot(processes, y_vals_min, marker='o', color='red', label='Min Time')
            plt.plot(processes, y_vals_max, marker='o', color='orange', label='Max Time')

            plt.xlabel("Number of Processes")
            plt.ylabel('Time (seconds)')
            plt.legend(loc=1, prop={'size': 9})
            plt.title(f'{node.frame["name"]} {m_size}x{m_size}')
            plt.savefig(f'results/{m_size}_{node.frame["name"]}.png', bbox_inches = 'tight')
            plt.show()
            plt.clf()
        
#         plot_pandas(
#             df=tk.dataframe.loc[node, "Total time"].unstack(level="matrix_size"),
#             title=node.frame["name"],
#             xlabel="Processes",
#             ylabel="Time (seconds)",
#         )

# %%
# !tar chvfz notebook.tar.gz results/
# Out:
# results/
# results/1024_master_initialization.png
# results/128_master_send_recieve.png
# results/8192_worker_calculation.png
# results/8192_master_send_recieve.png
# results/128_worker_recieve.png
# results/1024_master_send_recieve.png
# results/1024_worker_recieve.png
# results/8192_worker_send.png
# results/128_worker_send.png
# results/8192_whole_computation.png
# results/128_main.png
# results/8192_master_initialization.png
# results/8192_main.png
# results/1024_worker_calculation.png
# results/1024_main.png
# results/128_worker_calculation.png
# results/8192_worker_recieve.png
# results/128_whole_computation.png
# results/1024_worker_send.png
# results/128_master_initialization.png
# results/1024_whole_computation.png
